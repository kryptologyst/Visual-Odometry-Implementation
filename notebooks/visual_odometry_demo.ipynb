# %% [markdown]
# # Visual Odometry Implementation
#
# This notebook demonstrates the Visual Odometry implementation with different algorithms and evaluation metrics.
#
# **DISCLAIMER**: This is for educational and research purposes only. DO NOT use on real robots without proper safety measures and expert review.
